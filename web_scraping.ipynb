# %%
#
import requests
from bs4 import BeautifulSoup
import csv
from itertools import zip_longest
#
import pandas as pd

# %% [markdown]
# # in this project we will scrap thi [wep_page](https://wuzzuf.net/search/jobs/?q=python&a=hpb)

# %%
# use requests to fetch the url
result = requests.get("https://wuzzuf.net/search/jobs/?q=python&a=hpb")

# %%
#save the page content 
src = result.content

# %%
#create the soup object
soup = BeautifulSoup(src, 'lxml')

# %% [markdown]
# find all job titles

# %%
job_titles_liste = []
job_titles = soup.find_all("h2",{"class":"css-m604qf"} )
for job_title in job_titles:
 job_titles_liste.append( job_title.find('a').text)

job_titles_liste
# Out:
# ['Python Backend Developer',
#  'Senior Python / Django Developer',
#  'Python Developer',
#  'Senior Python Developer',
#  'Senior Python Engineer',
#  'Senior Python Developer',
#  'Senior Python Developer',
#  'Senior Python Backend Developer',
#  'Senior Full Stack Instructor (PHP - Python)',
#  'Python Developer For Job portal',
#  'Senior Python Linux Engineer',
#  'Senior Full Stack Developer',
#  'Backend Engineer',
#  'Software Engineer',
#  'Senior Software Developer']

# %%
links=[]

for job_title in job_titles:
 links.append(job_title.find("a").attrs['href'])
links
# Out:
# ['/jobs/p/A1z5DK0essUs-Python-Backend-Developer-Bydotpy-Cairo-Egypt?o=1&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/4yZylKxIEYZb-Senior-Python-Django-Developer-RDI-Giza-Egypt?o=2&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/TEXsA8hxgzA7-Python-Developer-OdooTec-Cairo-Egypt?o=3&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/6Yzv3ZC4RcGO-Senior-Python-Developer-Trufla-Cairo-Egypt?o=4&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/ohFtakW4EZWa-Senior-Python-Engineer-El-Sewedy-Electrometer-Giza-Egypt?o=5&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/X1RY331ukvMk-Senior-Python-Developer-FlairsTech-Cairo-Egypt?o=6&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/ybz0w5zmqwb1-Senior-Python-Developer-Houya-Arrow-Cairo-Egypt?o=7&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/1eIU4g1rGmID-Senior-Python-Backend-Developer-Tqniat-Lab-L-L-C-Cairo-Egypt?o=8&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/iYqxXkiFejBm-Senior-Full-Stack-Instructor-PHP---Python-Cairo-Egypt?o=9&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/KUTCuOGVL8tR-Python-Developer-For-Job-portal-Fekra-Technology-Solutions-and-Construction-Giza-Egypt?o=10&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/b1U2MrcQRbIO-Senior-Python-Linux-Engineer-El-Sewedy-Electrometer-Giza-Egypt?o=11&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/3irk407SkgH9-Senior-Full-Stack-Developer-Dafater-Cairo-Egypt?o=12&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/bxmBJw04oVXY-Backend-Engineer-Octo-Cairo-Egypt?o=13&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/o9OASkiHRSKK-Software-Engineer-Tam-Development-LLC-Riyadh-Saudi-Arabia?o=14&l=sp&t=sj&a=python|search-v3|hpb',
#  '/jobs/p/RJhYyffElQZX-Senior-Software-Developer-Sceel-io-Cairo-Egypt?o=15&l=sp&t=sj&a=python|search-v3|hpb']

# %% [markdown]
# find for evry job the skills needs

# %%
job_skills_liste = []
job_skills = soup.find_all("div",{"class":"css-y4udm8"})
for job_skill in job_skills:
 job_skills_liste.append( job_skill.text)
job_skills_liste
# Out:
# ['.css-1lh32fc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:8px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}.css-n2jc4m{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-text-decoration:none;text-decoration:none;color:inherit;margin-bottom:4px;}.css-adtuo7{cursor:pointer;padding:0 4px;border-radius:4px;}.css-1ve4b75{font-size:12px;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:20px;margin-right:4px;border-radius:2px;max-width:196px;white-space:nowrap;overflow:hidden;cursor:default;text-overflow:ellipsis;padding:2px 4px;background-color:#EBEDF0;color:#001433;cursor:pointer;padding:0 4px;border-radius:4px;}Full TimeExperienced · 6 - 10 Yrs of Exp · IT/Software Development · .css-5x9pm1{-webkit-text-decoration:none;text-decoration:none;color:inherit;max-width:calc(100vw / 2 - 32px);white-space:nowrap;overflow:hidden;text-overflow:ellipsis;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}Python · Django · Flask · RESTful API',
#  'Full TimeExperienced · 2+ Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Django · Python · MySQL · GIT · Docker · javaScript · Angular · RESTful APIs',
#  'Full TimeEntry Level · 1 - 2 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Odoo · MVC · Information Technology (IT) · Computer Science · Python · Software Development · CSS · Design',
#  'Full TimeExperienced · 4+ Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Agile · APIs · AWS · Computer Science · Git · Linux · Python · REST',
#  'Full TimeExperienced · 2 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Python · Computer Science · MySQL · Linux · Information Technology (IT) · SQL · jQuery · Programming',
#  'Full TimeExperienced · 3 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Applications · Computer Science · Design · Engineering · Implementation · Software Development · Information Technology (IT) · Mathematics',
#  'Full TimeExperienced · 3+ Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Python · Computer Science · Development · Software · Software Development · SDLC · Web · Web Applications',
#  'Full TimeWork From HomeExperienced · 3+ Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Python · Information Technology (IT) · Computer Science · Software Development · Django · Linux · NodeJS · MySQL',
#  'Full TimeExperienced · 6 - 7 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Training/Instructor · PHP · PHP Development · PHP Web Development · Python · python development · CSS3 · HTML5',
#  'Full TimeWork From HomeExperienced · 4+ Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · backend · Computer Science · Django · Flask · Git · Information Technology (IT) · postgres · Python',
#  'Full TimeExperienced · 3 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Software Development · Python · C++ · Information Technology (IT) · Computer Science · SQL · Programming · Electronics',
#  'Full TimeWork From HomeExperienced · 2 - 4 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Information Technology (IT) · Computer Science · Software Development · Software Engineering · Software · CSS · HTML · javaScript',
#  'Full TimeEntry Level · 0 - 2 Yrs of Exp · IT/Software Development · backend · python · Django',
#  'Full TimePart TimeWork From HomeExperienced · 5+ Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Computer Science · engineer · Information Technology (IT) · Software Development · Software Engineering · Software engineer · Software · Python',
#  'Full TimeExperienced · 3 - 7 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · CI/CD · Agile · DevOps · English · Python · REST · Software Development · Testing']

# %% [markdown]
# company names

# %%
company_names_liste = []
company_names = soup.find_all("a",{"class":"css-17s97q8"} )
for company_names in company_names:
 company_names_liste.append(company_names.text)
company_names_liste
# Out:
# ['Bydotpy -',
#  'RDI -',
#  'OdooTec -',
#  'Trufla -',
#  'El-Sewedy Electrometer -',
#  'FlairsTech -',
#  'Houya Arrow -',
#  'Tqniat Lab L.L.C -',
#  'Confidential -',
#  'Fekra Technology Solutions and Construction -',
#  'El-Sewedy Electrometer -',
#  'Dafater -',
#  'Octo -',
#  'Tam Development LLC -',
#  'Sceel.io -']

# %%
job_localisations_liste = []
job_localisations = soup.find_all("span",{"class":"css-5wys0k"} )
for job_localisation in job_localisations:
 job_localisations_liste.append( job_localisation.text)
job_localisations_liste
# Out:
# ['New Cairo, Cairo, Egypt ',
#  'Dokki, Giza, Egypt ',
#  'New Cairo, Cairo, Egypt ',
#  'Heliopolis, Cairo, Egypt ',
#  '6th of October, Giza, Egypt ',
#  'Maadi, Cairo, Egypt ',
#  'Heliopolis, Cairo, Egypt ',
#  'Nasr City, Cairo, Egypt ',
#  'Cairo, Egypt ',
#  'Dokki, Giza, Egypt ',
#  '6th of October, Giza, Egypt ',
#  'Nasr City, Cairo, Egypt ',
#  'Maadi, Cairo, Egypt ',
#  'Riyadh, Saudi Arabia ',
#  'Maadi, Cairo, Egypt ']

# %%
print(len(job_titles_liste),len(job_localisations_liste),len(job_skills_liste),len(company_names_liste))
# Out:
# 15 15 15 15

# %% [markdown]
# **now we can create a data set, from this data**

# %%
data = {"job_title":job_titles_liste,
        "company_name":company_names_liste,
        "job_localisation":job_localisations_liste,
        "job_skills":job_skills_liste,
        "job link": links
        }

df = pd.DataFrame(data)
print(df.shape)
df.head()
# Out:
# (15, 5)
#                           job_title              company_name  \
# 0          Python Backend Developer                 Bydotpy -
# 1  Senior Python / Django Developer                     RDI -
# 2                  Python Developer                 OdooTec -
# 3           Senior Python Developer                  Trufla -
# 4            Senior Python Engineer  El-Sewedy Electrometer -
#
#                job_localisation job_skills  \
# 0      New Cairo, Cairo, Egypt      Python
# 1           Dokki, Giza, Egypt    · Django
# 2      New Cairo, Cairo, Egypt      · Odoo
# 3     Heliopolis, Cairo, Egypt     · Agile
# 4  6th of October, Giza, Egypt      Python
#
#                                             job link
# 0  /jobs/p/A1z5DK0essUs-Python-Backend-Developer-...
# 1  /jobs/p/4yZylKxIEYZb-Senior-Python-Django-Deve...
# 2  /jobs/p/TEXsA8hxgzA7-Python-Developer-OdooTec-...
# 3  /jobs/p/6Yzv3ZC4RcGO-Senior-Python-Developer-T...
# 4  /jobs/p/ohFtakW4EZWa-Senior-Python-Engineer-El...

# %%
print(job_titles_liste[0])
# Out:
# .css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}Python Backend Developer

# %% [markdown]
# #create csv file

# %%
file_list=[job_titles_liste,
           company_names_liste,
       job_localisations_liste,
       job_skills_liste,
       links]
exported = zip_longest(*file_list)
with open("/content/sample_data/scraping_data.csv", "w") as file:
    wr = csv.writer(file)
    wr.writerow(["job title","company name","localisation","skills","job link"])
    wr.writerows(exported)
